# %%
import re
import json
import ast
import zipfile
import string
import openpyxl
import pandas as pd
import networkx as nx
import xml.etree.ElementTree as ET
from collections import defaultdict
from openpyxl import load_workbook
from oletools.olevba import VBA_Parser
import base64

# %%
from __XML__ import FULL_RUN, EXCEL_DATA_PARSER
from __XML__COMBINATION import XML_COMBINATION_DICT

# %%
FILE_NAME               = 'TEST_CASE.xlsm'
FUNC_PATH               = r'/Users/westhomas/Desktop/ALFRED/1__REPORT_AUTOMATION/XML_PROJECT/PROJECT_PART_1/ALFRED_AI/REFERENCE_FILES/FUNCTIONS.xlsx'
ROOT                    = r'/Users/westhomas/Desktop/ALFRED/1__REPORT_AUTOMATION/XML_PROJECT/PROJECT_PART_1/ALFRED_AI'
FILE_PATH               = ROOT + '/' + FILE_NAME

LABEL_OPTIONS           = ['SETTINGS', 'DATA_CONENECTION', 'INPUT_DATA', 'WORKING', 'OUTPUT']
INPUT_OPTIONS           = ['SQL', 'EXTERNAL_CONNECTION', 'PASTED', 'COMBINATION']
INPUT_CHOICE            = 2


LABELS                  = { 'Overview'              : 'SETTINGS',
                            'Mapping'               : 'INPUT_DATA',
                            'Instrument_Table'      : 'OUTPUT',
                            'DT_P'                  : 'DATA_CONENECTION',
                            'Sheet1'                : 'INPUT_DATA',
                            'Sheet2'                : 'INPUT_DATA',
                            'Sheet3'                : 'INPUT_DATA',
                            'Sheet4'                : 'INPUT_DATA',
                            'Sheet5'                : 'INPUT_DATA',
                            'o1'                    : 'WORKING',
                            'o2'                    : 'WORKING',
                            'o3'                    : 'WORKING',
                            'o4'                    : 'WORKING',
                            'o5'                    : 'WORKING',
                            'o10'                   : 'WORKING',
                            'OP-10'                 : 'WORKING',
                            'Unique_Items'          : 'WORKING',
                            'PAI'                   : 'INPUT_DATA',
                            'Reference'             : 'INPUT_DATA',
                            'FX'                    : 'INPUT_DATA',
                            'PMS'                   : 'INPUT_DATA',
                            'Port_ID'               : 'INPUT_DATA',
                            'FUNCS'                 : 'WORKING'
                        }

# %%
PARSED_DATA, EXTRACTOR, NESTED_OUTPUT, CLUSTERED_NESTED_OUTPUT, UPDATED_WORKSHEETS, OUTPUT_DETECTED_TABLES = FULL_RUN(FILE_PATH, FUNC_PATH, LABELS)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 PARSED_DATA, EXTRACTOR, NESTED_OUTPUT, CLUSTERED_NESTED_OUTPUT, UPDATED_WORKSHEETS, OUTPUT_DETECTED_TABLES = FULL_RUN(FILE_PATH, FUNC_PATH, LABELS)
#
# File ~/Desktop/ALFRED/1__REPORT_AUTOMATION/XML_PROJECT/PROJECT_PART_1/ALFRED_AI/__XML__.py:1399, in FULL_RUN(FILE_PATH, FUNC_PATH, LABELS)
#    1396 EXTRACTOR               = EXTRACT_FORMULAS(PARSED_DATA['WORKSHEETS'])
#    1397 FORMULA                 = FORMULA_ANALYZER(EXTRACTOR.DICT, FUNC_PATH)
# -> 1399 FORMULA.ANALYSE_FORMULAS()
#    1401 CROSS_REF               = CROSS_SHEET_REFERENCE_IDENTIFIER(EXTRACTOR.DICT)
#    1402 REFERENCES              = ADD_REFERENCES_TO_EXTRACTOR(EXTRACTOR.DICT, CROSS_REF.DICT)
#
# File ~/Desktop/ALFRED/1__REPORT_AUTOMATION/XML_PROJECT/PROJECT_PART_1/ALFRED_AI/__XML__.py:934, in FORMULA_ANALYZER.ANALYSE_FORMULAS(self)
#     932 FORMULA = CELL_DATA.get('FORMULA')
#     933 if FORMULA:
# --> 934     FORMULA_BREAKDOWN = self.FORMULA_CONVERSION(('='+FORMULA), OPERATORS_DF, FUNCTIONS_DF)
#     935     CELL_DATA['FORMULA_BREAKDOWN'] = FORMULA_BREAKDOWN
#
# File ~/Desktop/ALFRED/1__REPORT_AUTOMATION/XML_PROJECT/PROJECT_PART_1/ALFRED_AI/__XML__.py:973, in FORMULA_ANALYZER.FORMULA_CONVERSION(self, FORMULA, OPERATORS_DF, FUNCTIONS_DF)
#     971 FORMULA_LIST        = self.EXTRACTION(FORMULA)
#     972 FORMULA_CLEAN       = self.APPLY_OPERATORS(FORMULA, OPERATORS_DF)
# --> 973 RESULT              = self.PROCESS_FORMULA(FORMULA_CLEAN[1:], FUNCTIONS_DF, FORMULA_LIST)
#     975 return RESULT
#
# File ~/Desktop/ALFRED/1__REPORT_AUTOMATION/XML_PROJECT/PROJECT_PART_1/ALFRED_AI/__XML__.py:1026, in FORMULA_ANALYZER.PROCESS_FORMULA(self, FORMULA, FUNCTIONS_DF, FORMULA_LIST)
#    1020     return {"FUNCTION"      : "UNKNOWN",
#    1021             "COMPONENTS"    : { "FUNCTION_NAME" : TOP_FUNC_NAME,
#    1022                                 "ARGUMENTS"     : TOP_FUNC_ARGS}}
#    1024 if not TOP_FUNC_NAME:           return {}
# -> 1026 return self.JSON_OUTPUT(TOP_FUNC_NAME, TOP_FUNC_ARGS, FUNCTIONS_DF)
#
# File ~/Desktop/ALFRED/1__REPORT_AUTOMATION/XML_PROJECT/PROJECT_PART_1/ALFRED_AI/__XML__.py:1065, in FORMULA_ANALYZER.JSON_OUTPUT(self, FUNCTION_NAME, ARGUMENTS, FUNCTIONS_DF)
#    1063     NESTED_FUNCS_NAME                           = NESTED_FUNCS_MATCH.group(1)
#    1064     NESTED_FUNCS_ARGS                           = self.SPLIT_ARGUMENTS(NESTED_FUNCS_MATCH.group(2))
# -> 1065     COMPONENTS[JSON_FIELDS[i]]                  = self.JSON_OUTPUT(NESTED_FUNCS_NAME, NESTED_FUNCS_ARGS, FUNCTIONS_DF)
#    1067 else:
#    1068     if JSON_FIELDS[i] == "CONDITION":           COMPONENTS[JSON_FIELDS[i]] = self.PROCESS_CONDITIONS(ARGUMENTS[i].strip())
#
# File ~/Desktop/ALFRED/1__REPORT_AUTOMATION/XML_PROJECT/PROJECT_PART_1/ALFRED_AI/__XML__.py:1054, in FORMULA_ANALYZER.JSON_OUTPUT(self, FUNCTION_NAME, ARGUMENTS, FUNCTIONS_DF)
#    1053 def JSON_OUTPUT(self, FUNCTION_NAME, ARGUMENTS, FUNCTIONS_DF):
# -> 1054     JSON_FIELDS                                             = (FUNCTIONS_DF[FUNCTIONS_DF['EXCEL_FUNCTION']==FUNCTION_NAME].reset_index().iloc[:,1:]).at[0, 'JSON_FIELDS']
#    1056     if len(ARGUMENTS) == len(JSON_FIELDS):
#    1057         COMPONENTS = {}
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexing.py:2575, in _AtIndexer.__getitem__(self, key)
#    2572         raise ValueError("Invalid call for scalar access (getting)!")
#    2573     return self.obj.loc[key]
# -> 2575 return super().__getitem__(key)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexing.py:2527, in _ScalarAccessIndexer.__getitem__(self, key)
#    2524         raise ValueError("Invalid call for scalar access (getting)!")
#    2526 key = self._convert_key(key)
# -> 2527 return self.obj._get_value(*key, takeable=self._takeable)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:4221, in DataFrame._get_value(self, index, col, takeable)
#    4215 engine = self.index._engine
#    4217 if not isinstance(self.index, MultiIndex):
#    4218     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    4219     #  results if our categories are integers that dont match our codes
#    4220     # IntervalIndex: IntervalTree has no get_loc
# -> 4221     row = self.index.get_loc(index)
#    4222     return series._values[row]
#    4224 # For MultiIndex going through engine effectively restricts us to
#    4225 #  same-length tuples; see test_get_set_value_no_partial_indexing
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/range.py:415, in RangeIndex.get_loc(self, key)
#     413         return self._range.index(new_key)
#     414     except ValueError as err:
# --> 415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
#     417     raise KeyError(key)
#
# KeyError: 0

# %%
FINAL_DICT = XML_COMBINATION_DICT(PARSED_DATA, LABELS, OUTPUT_DETECTED_TABLES, CLUSTERED_NESTED_OUTPUT, NESTED_OUTPUT, UPDATED_WORKSHEETS, FILE_NAME, PROCESS_NAME, FREQUENCY, INSTANCE_DATE, INPUT_OPTIONS, INPUT_CHOICE)

# %%
def OTHER_INFO(FINAL_DICT, PARSED_DATA):

    def EXTRACT_DRAWING(DRAWDING):

        DRAWING_PRESENT = False
        for DRAWING_FILE, SHAPES in DRAWDING.items():
            if len(SHAPES) > 0 and DRAWING_PRESENT == False: DRAWING_PRESENT = True
                
        DRAWING_DATA = {'DRAWING_PRESENT' : DRAWING_PRESENT, "SHAPE_FEATURES" : []}
        for DRAWING_FILE, SHAPES in DRAWDING.items():
            for SHAPE in SHAPES:
                SHAPE_DATA = {  'TYPE'  : SHAPE.get('TYPE', 'N/A'),
                                'NAME'  : SHAPE.get('NAME', 'N/A'),
                                'MACRO' : SHAPE.get('MACRO', 'N/A'),
                                'TEXT'  : SHAPE.get('TEXT', 'N/A')}
                
                DRAWING_DATA['SHAPE_FEATURES'].append(SHAPE_DATA)
        return DRAWING_DATA



    SHAPE_DATA  = EXTRACT_DRAWING(PARSED_DATA['DRAWING'])
    VBA_DATA    = {"CODE_PRESENT"  : (False if len(PARSED_DATA['VBA']) == 0 else True), "CODE"          : []}
    PWQ_DATA    = {"CODE_PRESENT"  : (False if len(PARSED_DATA['PWQ']) == 0 else True), "CODE"          : []}


    if VBA_DATA['CODE_PRESENT'] == True:
        for a in range(len(PARSED_DATA['VBA'])):
            VBA_DRILL = {"ORDER"            : "NA",
                         "LOCATION_TYPE"    : "SHEET" if "SHEET" in PARSED_DATA['VBA'].at[a, 'VBA_FILENAME'].upper() else "MODULE",
                         "LOCATION"         : PARSED_DATA['VBA'].at[a, 'VBA_FILENAME'],
                         "SCRIPT"           : PARSED_DATA['VBA'].at[a, 'VBA_CODE']}
        
            VBA_DATA['CODE'].append(VBA_DRILL)


    if PWQ_DATA['CODE_PRESENT'] == True:
        for a in range(len(PARSED_DATA['PWQ'])):
            PWQ_DRILL = {"ORDER"            : "NA",
                         "CONNECTION_NAME"  : PARSED_DATA['PWQ'].at[a, 'NAME'],
                         "REFERENCE_TABLE"  : PARSED_DATA['PWQ'].at[a, 'REFERENCE'],
                         "CONNECTION_TYPE"  : PARSED_DATA['PWQ'].at[a, 'TYPE'],
                         "SCRIPT"           : PARSED_DATA['PWQ'].at[a, 'M_CODE']}
        
            PWQ_DATA['CODE'].append(PWQ_DRILL)




    MODEL_DATA = ''


    FINAL_DICT['SHAPES']            = SHAPE_DATA
    FINAL_DICT['VBA']               = VBA_DATA
    FINAL_DICT['POWER_QUERY']       = PWQ_DATA
    FINAL_DICT['DATA_MODEL']        = MODEL_DATA
    FINAL_DICT['STYLE_USED']        = PARSED_DATA['STYLES']
    FINAL_DICT['THEME_USED']        = {'THEME_APPLIED' : PARSED_DATA['THEME']['color_scheme']}

    return FINAL_DICT

# %%
FILE_NAME               = 'TEST_CASE.xlsm'
FUNC_PATH               = r'/Users/westhomas/Desktop/ALFRED/1__REPORT_AUTOMATION/XML_PROJECT/PROJECT_PART_1/ALFRED_AI/REFERENCE_FILES/FUNCTIONS.xlsx'
ROOT                    = r'/Users/westhomas/Desktop/ALFRED/1__REPORT_AUTOMATION/XML_PROJECT/PROJECT_PART_1/ALFRED_AI'
FILE_PATH               = ROOT + '/' + FILE_NAME

LABEL_OPTIONS           = ['SETTINGS', 'DATA_CONENECTION', 'INPUT_DATA', 'WORKING', 'OUTPUT']
INPUT_OPTIONS           = ['SQL', 'EXTERNAL_CONNECTION', 'PASTED', 'COMBINATION']
INPUT_CHOICE            = 2


LABELS                  = { 'Overview'              : 'SETTINGS',
                            'Mapping'               : 'INPUT_DATA',
                            'Instrument_Table'      : 'OUTPUT',
                            'DT_P'                  : 'DATA_CONENECTION',
                            'Sheet1'                : 'INPUT_DATA',
                            'Sheet2'                : 'INPUT_DATA',
                            'Sheet3'                : 'INPUT_DATA',
                            'Sheet4'                : 'INPUT_DATA',
                            'Sheet5'                : 'INPUT_DATA',
                            'o1'                    : 'WORKING',
                            'o2'                    : 'WORKING',
                            'o3'                    : 'WORKING',
                            'o4'                    : 'WORKING',
                            'o5'                    : 'WORKING',
                            'o10'                   : 'WORKING',
                            'OP-10'                 : 'WORKING',
                            'Unique_Items'          : 'WORKING',
                            'PAI'                   : 'INPUT_DATA',
                            'Reference'             : 'INPUT_DATA',
                            'FX'                    : 'INPUT_DATA',
                            'PMS'                   : 'INPUT_DATA',
                            'Port_ID'               : 'INPUT_DATA',
                            'FUNCS'                 : 'WORKING'
                        }



EXCEL_PARSED            = EXCEL_DATA_PARSER(FILE_PATH, LABELS)
OUTPUT                  = EXCEL_PARSED.GET_DATA()
OUTPUT['EXT']
# Out:
# {'xl/drawings/drawing1.xml': [{'TYPE': 'SHAPE',
#    'NAME': 'Rectangle: Rounded Corners 1',
#    'MACRO': 'Sheet2.Full_Process',
#    'TEXT': 'Stage 1 Retrieve Data'},
#   {'TYPE': 'SHAPE',
#    'NAME': 'Rectangle: Rounded Corners 2',
#    'MACRO': 'Sheet2.Process_Changes',
#    'TEXT': 'Stage  3 Run Process'},
#   {'TYPE': 'SHAPE',
#    'NAME': 'Rectangle: Rounded Corners 3',
#    'MACRO': 'Sheet2.Process_complete',
#    'TEXT': 'Stage  4 Final  SOF Processes'},
#   {'TYPE': 'SHAPE',
#    'NAME': 'Rectangle: Rounded Corners 4',
#    'MACRO': 'Sheet2.PASTING',
#    'TEXT': 'Stage  2 Formatting'},
#   {'TYPE': 'SHAPE',
#    'NAME': 'Rectangle: Rounded Corners 5',
#    'MACRO': 'Sheet2.SCALING_FINAL',
#    'TEXT': 'Stage  5 Final  EET Processes'},
#   {'TYPE': 'SHAPE',
#    'NAME': 'Rectangle: Rounded Corners 6',
#    'MACRO': 'Sheet2.Export_File',
#    'TEXT': 'Stage  6 Export File'},
#   {'TYPE': 'SHAPE',
#    'NAME': 'Rectangle: Rounded Corners 7',
#    'MACRO': 'Sheet2.Full_Run',
#    'TEXT': 'All  Stages Full Process Run'}],
#  'xl/drawings/drawing2.xml': []}

# %%
class EXCEL_XML_EXTRACTOR:
    def __init__(self, FILE_PATH):
        self.FILE_PATH = FILE_PATH
        self.XML_FILES = self.EXTRACT_XML_FILES()

    def EXTRACT_XML_FILES(self):
        XML_FILES = {}
        with zipfile.ZipFile(self.FILE_PATH, 'r') as ZIP_REF:
            for FILE in ZIP_REF.namelist():
                if FILE.endswith('.xml'):
                    with ZIP_REF.open(FILE) as f:
                        XML_FILES[FILE] = f.read()
        return XML_FILES

# %%
class DRAWING_PARSING:

    def __init__(self, XML_FILES):
        self.XML_FILES = XML_FILES
        self.DICT = self.DRAWING_PARSE()

    def DRAWING_PARSE(self):
        DRAWINGS = {}
        for FILE_NAME, XML_CONTENT in self.XML_FILES.items():
            if 'xl/drawings/drawing' in FILE_NAME:
                ROOT = ET.fromstring(XML_CONTENT)
                DRAWING_INFO = []

                # Namespaces
                NAMESPACES = {
                    'A': 'http://schemas.openxmlformats.org/drawingml/2006/main',
                    'XDR': 'http://schemas.openxmlformats.org/drawingml/2006/spreadsheetDrawing'
                }

                # Loop through shapes only
                for ANCHOR in ROOT.findall('XDR:twoCellAnchor', NAMESPACES):
                    SHAPE_INFO = {}
                    SP = ANCHOR.find('XDR:sp', NAMESPACES)
                    
                    if SP is not None:
                        # Shape name and macro attributes
                        SP_NAME = SP.find('XDR:nvSpPr/XDR:cNvPr', NAMESPACES)
                        if SP_NAME is not None:
                            SHAPE_INFO['TYPE'] = 'SHAPE'
                            SHAPE_INFO['NAME'] = SP_NAME.attrib.get('name', 'Unnamed Shape')

                            # Capture macro text after "!"
                            MACRO_TEXT = SP.attrib.get('macro', None)
                            if MACRO_TEXT and "!" in MACRO_TEXT:
                                SHAPE_INFO['MACRO'] = MACRO_TEXT.split("!")[1]
                            else:
                                SHAPE_INFO['MACRO'] = 'No Macro Assigned'

                        # Extract text within shape
                        TEXT_ELEMENTS = SP.findall('.//A:t', NAMESPACES)
                        SHAPE_INFO['TEXT'] = ' '.join([ELEM.text for ELEM in TEXT_ELEMENTS if ELEM.text]) if TEXT_ELEMENTS else 'No Text Content'

                        DRAWING_INFO.append(SHAPE_INFO)

                DRAWINGS[FILE_NAME] = DRAWING_INFO

        return DRAWINGS

# %%
class EXCEL_DATA_PARSER:


    def __init__(self, FILE_PATH, LABELS):
        self.XML_EXTRACTOR      = EXCEL_XML_EXTRACTOR(FILE_PATH)
        self.EXT                = DRAWING_PARSING(self.XML_EXTRACTOR.XML_FILES)

        
    def GET_DATA(self):
        return {'XML'               : self.XML_EXTRACTOR.XML_FILES,
                'EXT'               : self.EXT.DICT}
