# %%
import re
import json
import ast
import zipfile
import string
import openpyxl
import pandas as pd
import networkx as nx
import xml.etree.ElementTree as ET
from collections import defaultdict
from openpyxl import load_workbook
from oletools.olevba import VBA_Parser
import base64

# %%
from __XML__ import FULL_RUN, EXCEL_DATA_PARSER
from __XML__COMBINATION import XML_COMBINATION_DICT

# %%
FILE_NAME               = 'TEST_CASE.xlsm'
FUNC_PATH               = r'/Users/westhomas/Desktop/ALFRED/1__REPORT_AUTOMATION/XML_PROJECT/PROJECT_PART_1/ALFRED_AI/REFERENCE_FILES/FUNCTIONS.xlsx'
ROOT                    = r'/Users/westhomas/Desktop/ALFRED/1__REPORT_AUTOMATION/XML_PROJECT/PROJECT_PART_1/ALFRED_AI'
FILE_PATH               = ROOT + '/' + FILE_NAME

LABEL_OPTIONS           = ['SETTINGS', 'DATA_CONENECTION', 'INPUT_DATA', 'WORKING', 'OUTPUT']
INPUT_OPTIONS           = ['SQL', 'EXTERNAL_CONNECTION', 'PASTED', 'COMBINATION']
INPUT_CHOICE            = 2


LABELS                  = { 'Overview'              : 'SETTINGS',
                            'Mapping'               : 'INPUT_DATA',
                            'Instrument_Table'      : 'OUTPUT',
                            'DT_P'                  : 'DATA_CONENECTION',
                            'Sheet1'                : 'INPUT_DATA',
                            'Sheet2'                : 'INPUT_DATA',
                            'Sheet3'                : 'INPUT_DATA',
                            'Sheet4'                : 'INPUT_DATA',
                            'Sheet5'                : 'INPUT_DATA',
                            'o1'                    : 'WORKING',
                            'o2'                    : 'WORKING',
                            'o3'                    : 'WORKING',
                            'o4'                    : 'WORKING',
                            'o5'                    : 'WORKING',
                            'o10'                   : 'WORKING',
                            'OP-10'                 : 'WORKING',
                            'Unique_Items'          : 'WORKING',
                            'PAI'                   : 'INPUT_DATA',
                            'Reference'             : 'INPUT_DATA',
                            'FX'                    : 'INPUT_DATA',
                            'PMS'                   : 'INPUT_DATA',
                            'Port_ID'               : 'INPUT_DATA',
                            'FUNCS'                 : 'WORKING'
                        }

# %%
FILE_NAME               = 'EXCL_TEST_REVISED.xlsx'
PROCESS_NAME            = 'TEST_CASE'
FREQUENCY               = "QUARTERLY"
INSTANCE_DATE           = "01.01.2024"

FUNC_PATH               = r'/Users/westhomas/Desktop/ALFRED/1__REPORT_AUTOMATION/XML_PROJECT/PROJECT_PART_1/ALFRED_AI/REFERENCE_FILES/FUNCTIONS.xlsx'
ROOT                    = r'/Users/westhomas/Desktop/ALFRED/1__REPORT_AUTOMATION/XML_PROJECT/PROJECT_PART_1/ALFRED_AI'
FILE_PATH               = ROOT + '/' + FILE_NAME

LABELS                  = { 'INPUT_1'   : 'OUTPUT',
                            'INPUT_2'   : 'INPUT_DATA',
                            'OUTPUT_1'  : 'OUTPUT',
                            'OUTPUT_2'  : 'OUTPUT'}

LABEL_OPTIONS           = ['SETTINGS', 'DATA_CONENECTION', 'INPUT_DATA', 'WORKING', 'OUTPUT']
INPUT_OPTIONS           = ['SQL', 'EXTERNAL_CONNECTION', 'PASTED', 'COMBINATION']
INPUT_CHOICE            = 2

# %%
PARSED_DATA, EXTRACTOR, NESTED_OUTPUT, CLUSTERED_NESTED_OUTPUT, UPDATED_WORKSHEETS, OUTPUT_DETECTED_TABLES, P3_RESULTS = FULL_RUN(FILE_PATH, FUNC_PATH, LABELS)

# %%
FINAL_DICT, DESIRED_OUTPUT = XML_COMBINATION_DICT(PARSED_DATA, LABELS, OUTPUT_DETECTED_TABLES, CLUSTERED_NESTED_OUTPUT, NESTED_OUTPUT, UPDATED_WORKSHEETS, FILE_NAME, PROCESS_NAME, FREQUENCY, INSTANCE_DATE, INPUT_OPTIONS, INPUT_CHOICE, P3_RESULTS)

# %%
FINAL_DICT
# Out:
# {'WORKBOOK': {'FILENAME': 'EXCL_TEST_REVISED',
#   'PROCESS_NAME': 'TEST_CASE',
#   'FREQUENCY': 'QUARTERLY',
#   'INSTANCE_DATE': '01.01.2024'},
#  'WORKSHEETS': {'WORKSHEETS': {'INPUT_2': {'SHEET_TYPE': 'INPUT_DATA',
#     'TABLE_PRESENT': False,
#     'TABLE_PARAMS': {},
#     'PIVOT_PRESENT': False,
#     'PIVOT_PARAMS': {},
#     'NAMED_RANGE_PRESENT': False,
#     'NAMED_RANGE_PARAMS': [],
#     'CLUSTERS': [{'TABLE_TYPE': 'CLUSTER',
#       'TABLE_RANGE': False,
#       'PIVOT_RANGE': False,
#       'START_CELL': 'A1',
#       'HEADER': {'A': 'GUIDE', 'B': 'OUTPUT'},
#       'ROWS': 6,
#       'COLUMNS': 2,
#       'REF_CELLS': ['A1',
#        'A2',
#        'A3',
#        'A4',
#        'A5',
#        'A6',
#        'B1',
#        'B2',
#        'B3',
#        'B4',
#        'B5',
#        'B6'],
#       'COLUMN': [{'COLUMN_LETTER': 'A',
#         'COLUMN_HEADER': 'GUIDE',
#         'FORMULA': False,
#         'NESTED_STRING': 'NA',
#         'NESTED_FUNCTION': {},
#         'NESTED_CLUSTER': [],
#         'CELLS': {'A1': {'TYPE': 's',
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': 'GUIDE',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}},
#          'A2': {'TYPE': None,
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': '1',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}},
#          'A3': {'TYPE': None,
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': '2',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}},
#          'A4': {'TYPE': None,
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': '3',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}},
#          'A5': {'TYPE': None,
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': '4',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}},
#          'A6': {'TYPE': None,
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': '5',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}}}},
#        {'COLUMN_LETTER': 'B',
#         'COLUMN_HEADER': 'OUTPUT',
#         'FORMULA': False,
#         'NESTED_STRING': 'NA',
#         'NESTED_FUNCTION': {},
#         'NESTED_CLUSTER': [],
#         'CELLS': {'B1': {'TYPE': 's',
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': 'OUTPUT',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}},
#          'B2': {'TYPE': None,
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': '10',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}},
#          'B3': {'TYPE': None,
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': '20',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}},
#          'B4': {'TYPE': None,
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': '30',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}},
#          'B5': {'TYPE': None,
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': '40',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}},
#          'B6': {'TYPE': None,
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': '50',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}}}}]}]},
#    'OUTPUT_1': {'SHEET_TYPE': 'OUTPUT',
#     'TABLE_PRESENT': False,
#     'TABLE_PARAMS': {},
#     'PIVOT_PRESENT': True,
#     'PIVOT_PARAMS': {'NAME': 'PT_1',
#      'LOCATION': 'A3:B5',
#      'CONTENTS': {'ROWS': ['HELP'],
#       'COLUMNS': [],
#       'DATA': ['TESTING'],
#       'FILTERS': []},
#      'SOURCE_TABLE': True,
#      'SOURCE_INFO': {'NAME': 'Table1', 'SHEET': None, 'LOCATION': None}},
#     'NAMED_RANGE_PRESENT': False,
#     'NAMED_RANGE_PARAMS': [],
#     'CLUSTERS': [{'TABLE_TYPE': 'PIVOT',
#       'TABLE_RANGE': False,
#       'PIVOT_RANGE': True,
#       'START_CELL': 'A3',
#       'HEADER': {'A': None, 'B': None},
#       'ROWS': 3,
#       'COLUMNS': 2,
#       'REF_CELLS': ['A3', 'A4', 'A5', 'B3', 'B4', 'B5'],
#       'COLUMN': [{'COLUMN_LETTER': 'A',
#         'COLUMN_HEADER': None,
#         'FORMULA': False,
#         'NESTED_STRING': 'NA',
#         'NESTED_FUNCTION': {},
#         'NESTED_CLUSTER': [],
#         'CELLS': {'A3': {'TYPE': 's',
#           'STYLE_INDEX': '4',
#           'FORMULA': None,
#           'VALUE': 'Row Labels',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}},
#          'A4': {'TYPE': None,
#           'STYLE_INDEX': '5',
#           'FORMULA': None,
#           'VALUE': '1',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}},
#          'A5': {'TYPE': 's',
#           'STYLE_INDEX': '5',
#           'FORMULA': None,
#           'VALUE': 'Grand Total',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}}}},
#        {'COLUMN_LETTER': 'B',
#         'COLUMN_HEADER': None,
#         'FORMULA': False,
#         'NESTED_STRING': 'NA',
#         'NESTED_FUNCTION': {},
#         'NESTED_CLUSTER': [],
#         'CELLS': {'B3': {'TYPE': 's',
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': 'Sum of TESTING',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}},
#          'B4': {'TYPE': None,
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': '2',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}},
#          'B5': {'TYPE': None,
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': '2',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}}}}]}]},
#    'OUTPUT_2': {'SHEET_TYPE': 'OUTPUT',
#     'TABLE_PRESENT': False,
#     'TABLE_PARAMS': {},
#     'PIVOT_PRESENT': True,
#     'PIVOT_PARAMS': {'NAME': 'PT_2',
#      'LOCATION': 'A3:C7',
#      'CONTENTS': {'ROWS': ['TEST_CELL'],
#       'COLUMNS': ['REFERECE'],
#       'DATA': ['FORMULA'],
#       'FILTERS': []},
#      'SOURCE_TABLE': False,
#      'SOURCE_INFO': {'NAME': None, 'SHEET': 'INPUT_1', 'LOCATION': 'A1:C3'}},
#     'NAMED_RANGE_PRESENT': False,
#     'NAMED_RANGE_PARAMS': [],
#     'CLUSTERS': [{'TABLE_TYPE': 'PIVOT',
#       'TABLE_RANGE': False,
#       'PIVOT_RANGE': True,
#       'START_CELL': 'A3',
#       'HEADER': {'A': None, 'B': None, 'C': None},
#       'ROWS': 5,
#       'COLUMNS': 3,
#       'REF_CELLS': ['A3',
#        'A4',
#        'A5',
#        'A6',
#        'A7',
#        'B3',
#        'B4',
#        'B5',
#        'B6',
#        'B7',
#        'C4',
#        'C5',
#        'C6',
#        'C7'],
#       'COLUMN': [{'COLUMN_LETTER': 'A',
#         'COLUMN_HEADER': None,
#         'FORMULA': False,
#         'NESTED_STRING': 'NA',
#         'NESTED_FUNCTION': {},
#         'NESTED_CLUSTER': [],
#         'CELLS': {'A3': {'TYPE': 's',
#           'STYLE_INDEX': '4',
#           'FORMULA': None,
#           'VALUE': 'Sum of FORMULA',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}},
#          'A4': {'TYPE': 's',
#           'STYLE_INDEX': '4',
#           'FORMULA': None,
#           'VALUE': 'Row Labels',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}},
#          'A5': {'TYPE': None,
#           'STYLE_INDEX': '5',
#           'FORMULA': None,
#           'VALUE': '2',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}},
#          'A6': {'TYPE': None,
#           'STYLE_INDEX': '5',
#           'FORMULA': None,
#           'VALUE': '1',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}},
#          'A7': {'TYPE': 's',
#           'STYLE_INDEX': '5',
#           'FORMULA': None,
#           'VALUE': 'Grand Total',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}}}},
#        {'COLUMN_LETTER': 'B',
#         'COLUMN_HEADER': None,
#         'FORMULA': False,
#         'NESTED_STRING': 'NA',
#         'NESTED_FUNCTION': {},
#         'NESTED_CLUSTER': [],
#         'CELLS': {'B3': {'TYPE': 's',
#           'STYLE_INDEX': '4',
#           'FORMULA': None,
#           'VALUE': 'Column Labels',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}},
#          'B4': {'TYPE': None,
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': '1',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}},
#          'B5': {'TYPE': None,
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': '10',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}},
#          'B6': {'TYPE': None,
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': '10',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}},
#          'B7': {'TYPE': None,
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': '20',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}}}},
#        {'COLUMN_LETTER': 'C',
#         'COLUMN_HEADER': None,
#         'FORMULA': False,
#         'NESTED_STRING': 'NA',
#         'NESTED_FUNCTION': {},
#         'NESTED_CLUSTER': [],
#         'CELLS': {'C4': {'TYPE': 's',
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': 'Grand Total',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}},
#          'C5': {'TYPE': None,
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': '10',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}},
#          'C6': {'TYPE': None,
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': '10',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}},
#          'C7': {'TYPE': None,
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': '20',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}}}}]}]},
#    'INPUT_1': {'SHEET_TYPE': 'OUTPUT',
#     'TABLE_PRESENT': True,
#     'TABLE_PARAMS': {'NAME': 'Table1',
#      'START_CELL': 'I1',
#      'LOCATION': 'I1:J2',
#      'DIMENSIONS': {'ROWS': 2, 'COLUMNS': None},
#      'COLUMNS': ['HELP', 'TESTING']},
#     'PIVOT_PRESENT': False,
#     'PIVOT_PARAMS': {},
#     'NAMED_RANGE_PRESENT': True,
#     'NAMED_RANGE_PARAMS': [{'NAME': 'TEST_RANGE',
#       'SHEET_NAME': 'INPUT_1',
#       'START_CELL': 'N1',
#       'REF': 'N1',
#       'DIMENSIONS': {'ROWS': 1, 'COLUMNS': 1}}],
#     'CLUSTERS': [{'TABLE_TYPE': 'CLUSTER',
#       'TABLE_RANGE': False,
#       'PIVOT_RANGE': False,
#       'START_CELL': 'A1',
#       'HEADER': {'A': 'REFERECE', 'B': 'TEST_CELL', 'C': 'FORMULA'},
#       'ROWS': 3,
#       'COLUMNS': 3,
#       'REF_CELLS': ['A1', 'A2', 'A3', 'B1', 'B2', 'B3', 'C1', 'C2', 'C3'],
#       'COLUMN': [{'COLUMN_LETTER': 'A',
#         'COLUMN_HEADER': 'REFERECE',
#         'FORMULA': False,
#         'NESTED_STRING': 'NA',
#         'NESTED_FUNCTION': {},
#         'NESTED_CLUSTER': [],
#         'CELLS': {'A1': {'TYPE': 's',
#           'STYLE_INDEX': '1',
#           'FORMULA': None,
#           'VALUE': 'REFERECE',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}},
#          'A2': {'TYPE': None,
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': '1',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 1,
#            'ANCESTORS': [],
#            'DESCENDENTS': ['INPUT_1!C2']}},
#          'A3': {'TYPE': None,
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': '1',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 1,
#            'ANCESTORS': [],
#            'DESCENDENTS': ['INPUT_1!C3']}}}},
#        {'COLUMN_LETTER': 'B',
#         'COLUMN_HEADER': 'TEST_CELL',
#         'FORMULA': False,
#         'NESTED_STRING': 'NA',
#         'NESTED_FUNCTION': {},
#         'NESTED_CLUSTER': [],
#         'CELLS': {'B1': {'TYPE': 's',
#           'STYLE_INDEX': '2',
#           'FORMULA': None,
#           'VALUE': 'TEST_CELL',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}},
#          'B2': {'TYPE': None,
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': '2',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 1,
#            'ANCESTORS': [],
#            'DESCENDENTS': ['INPUT_1!C2']}},
#          'B3': {'TYPE': None,
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': '1',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 1,
#            'ANCESTORS': [],
#            'DESCENDENTS': ['INPUT_1!C3']}}}},
#        {'COLUMN_LETTER': 'C',
#         'COLUMN_HEADER': 'FORMULA',
#         'FORMULA': False,
#         'NESTED_STRING': 'IF|{"CONDITION":"NONE!A*!=NONE!B*","TRUE":{"FUNCTION":"VLOOKUP","COMPONENTS":{"LOOKUP_VALUE":"NONE!A*","TABLE_ARRAY":"INPUT_2!A:B","COL_INDEX_NUM":"2","RANGE_LOOKUP":"0"}},"FALSE":{"FUNCTION":"VLOOKUP","COMPONENTS":{"LOOKUP_VALUE":"NONE!B*","TABLE_ARRAY":"INPUT_2!A:B","COL_INDEX_NUM":"2","RANGE_LOOKUP":"0"}}}',
#         'NESTED_FUNCTION': {'FUNCTION': 'IF',
#          'COMPONENTS': {'CONDITION': 'NONE!A*!=NONE!B*',
#           'TRUE': {'FUNCTION': 'VLOOKUP',
#            'COMPONENTS': {'LOOKUP_VALUE': 'NONE!A*',
#             'TABLE_ARRAY': 'INPUT_2!A:B',
#             'COL_INDEX_NUM': '2',
#             'RANGE_LOOKUP': '0'}},
#           'FALSE': {'FUNCTION': 'VLOOKUP',
#            'COMPONENTS': {'LOOKUP_VALUE': 'NONE!B*',
#             'TABLE_ARRAY': 'INPUT_2!A:B',
#             'COL_INDEX_NUM': '2',
#             'RANGE_LOOKUP': '0'}}}},
#         'NESTED_CLUSTER': ['C2', 'C3'],
#         'CELLS': {'C1': {'TYPE': 's',
#           'STYLE_INDEX': '3',
#           'FORMULA': None,
#           'VALUE': 'FORMULA',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}},
#          'C2': {'TYPE': None,
#           'STYLE_INDEX': None,
#           'FORMULA': 'IF(A2<>B2,VLOOKUP(A2,INPUT_2!A:B,2,0),VLOOKUP(B2,INPUT_2!A:B,2,0))',
#           'VALUE': '10',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 3,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': ['INPUT_1!A2', 'INPUT_2!A:B', 'INPUT_1!B2'],
#            'DESCENDENTS': []}},
#          'C3': {'TYPE': None,
#           'STYLE_INDEX': None,
#           'FORMULA': 'IF(A3<>B3,VLOOKUP(A3,INPUT_2!A:B,2,0),VLOOKUP(B3,INPUT_2!A:B,2,0))',
#           'VALUE': '10',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 3,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': ['INPUT_1!A3', 'INPUT_2!A:B', 'INPUT_1!B3'],
#            'DESCENDENTS': []}}}}]},
#      {'TABLE_TYPE': 'TABLE',
#       'TABLE_RANGE': True,
#       'PIVOT_RANGE': False,
#       'START_CELL': 'I1',
#       'HEADER': {'I': 'HELP', 'J': 'TESTING'},
#       'ROWS': 2,
#       'COLUMNS': 2,
#       'REF_CELLS': ['I1', 'I2', 'J1', 'J2'],
#       'COLUMN': [{'COLUMN_LETTER': 'I',
#         'COLUMN_HEADER': 'HELP',
#         'FORMULA': False,
#         'NESTED_STRING': 'NA',
#         'NESTED_FUNCTION': {},
#         'NESTED_CLUSTER': [],
#         'CELLS': {'I1': {'TYPE': 's',
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': 'HELP',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}},
#          'I2': {'TYPE': None,
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': '1',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}}}},
#        {'COLUMN_LETTER': 'J',
#         'COLUMN_HEADER': 'TESTING',
#         'FORMULA': False,
#         'NESTED_STRING': 'NA',
#         'NESTED_FUNCTION': {},
#         'NESTED_CLUSTER': [],
#         'CELLS': {'J1': {'TYPE': 's',
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': 'TESTING',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}},
#          'J2': {'TYPE': None,
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': '2',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}}}}]},
#      {'TABLE_TYPE': 'CLUSTER',
#       'TABLE_RANGE': False,
#       'PIVOT_RANGE': False,
#       'START_CELL': 'N1',
#       'HEADER': {'N': '1'},
#       'ROWS': 1,
#       'COLUMNS': 1,
#       'REF_CELLS': ['N1'],
#       'COLUMN': [{'COLUMN_LETTER': 'N',
#         'COLUMN_HEADER': '1',
#         'FORMULA': False,
#         'NESTED_STRING': 'NA',
#         'NESTED_FUNCTION': {},
#         'NESTED_CLUSTER': [],
#         'CELLS': {'N1': {'TYPE': None,
#           'STYLE_INDEX': None,
#           'FORMULA': None,
#           'VALUE': '1',
#           'DEPENDENCY': {'ANCESTORS_LENGTH': 0,
#            'DESCENDENTS_LENGTH': 0,
#            'ANCESTORS': [],
#            'DESCENDENTS': []}}}}]}]}}},
#  'DEPENDENCY_GRAPH': [('INPUT_1!C2', 3),
#   ('INPUT_1!C3', 3),
#   ('INPUT_1!A2', 0),
#   ('INPUT_1!B2', 0),
#   ('INPUT_2!A:B', 0),
#   ('INPUT_1!A3', 0),
#   ('INPUT_1!B3', 0)],
#  'CALCULATION_ORDER': [{'CELL_REF': 'C3', 'SHEET_NAME': 'OUTPUT_2'},
#   {'CELL_REF': 'C2', 'SHEET_NAME': 'OUTPUT_2'}],
#  'INPUT_TYPE': {'INPUT_DATA_TYPE': 'PASTED',
#   'SQL_FUNCS_CALL': 'STILL TO BE DEVELOPED',
#   'EXT_CON_LOCATIONS': 'STILL TO BE DEVELOPED',
#   'PASTED_DATA_SOURCE': 'STILL TO BE DEVELOPED',
#   'INPUT_DATA_SHEETS': ['INPUT_2']},
#  'SHAPES': {'DRAWING_PRESENT': False, 'SHAPE_FEATURES': []},
#  'VBA': {'CODE_PRESENT': False, 'CODE': []},
#  'POWER_QUERY': {'CODE_PRESENT': False, 'CODE': []},
#  'DATA_MODEL': '',
#  'STYLE_USED': {'NUMBER_FORMATS': {},
#   'FONTS': [{'NAME': 'Calibri',
#     'SIZE': '11',
#     'BOLD': False,
#     'ITALIC': False,
#     'COLOR': None},
#    {'NAME': 'Calibri',
#     'SIZE': '11',
#     'BOLD': True,
#     'ITALIC': False,
#     'COLOR': None},
#    {'NAME': 'Calibri',
#     'SIZE': '11',
#     'BOLD': False,
#     'ITALIC': True,
#     'COLOR': None},
#    {'NAME': 'Arial',
#     'SIZE': '11',
#     'BOLD': False,
#     'ITALIC': False,
#     'COLOR': None}],
#   'FILLS': [{'PATTERN_TYPE': 'none', 'FG_COLOR': None, 'BG_COLOR': None},
#    {'PATTERN_TYPE': 'gray125', 'FG_COLOR': None, 'BG_COLOR': None},
#    {'PATTERN_TYPE': 'solid', 'FG_COLOR': 'FFFFFF00', 'BG_COLOR': None}],
#   'BORDERS': [{'LEFT': True, 'RIGHT': True, 'TOP': True, 'BOTTOM': True}],
#   'CELLXFS': [{'NUM_FMT_ID': '0',
#     'FONT_ID': '0',
#     'FILL_ID': '0',
#     'BORDER_ID': '0'},
#    {'NUM_FMT_ID': '0', 'FONT_ID': '1', 'FILL_ID': '0', 'BORDER_ID': '0'},
#    {'NUM_FMT_ID': '0', 'FONT_ID': '2', 'FILL_ID': '0', 'BORDER_ID': '0'},
#    {'NUM_FMT_ID': '0', 'FONT_ID': '3', 'FILL_ID': '2', 'BORDER_ID': '0'},
#    {'NUM_FMT_ID': '0', 'FONT_ID': '0', 'FILL_ID': '0', 'BORDER_ID': '0'},
#    {'NUM_FMT_ID': '0', 'FONT_ID': '0', 'FILL_ID': '0', 'BORDER_ID': '0'}]},
#  'THEME_USED': {'THEME_APPLIED': ['44546A',
#    'E7E6E6',
#    '4472C4',
#    'ED7D31',
#    'A5A5A5',
#    'FFC000',
#    '5B9BD5',
#    '70AD47',
#    '0563C1',
#    '954F72']}}

# %%
def identify_formula_type(formula, named_ranges):
    # Check for array formulas
    if any(func in formula for func in ["SUMPRODUCT", "FILTER", "UNIQUE", "SEQUENCE"]):
        return "Array Formula"
    
    # Check for INDIRECT references
    elif "INDIRECT" in formula:
        return "INDIRECT Reference"
    
    # Check for named ranges
    elif any(named_range in formula for named_range in named_ranges):
        return "Named Range"
    
    # Check for table column references
    elif re.search(r"\[\w+\]", formula):
        return "Table Column Reference"
    
    else:
        return "Standard Formula"

# Example usage:
formula = "VLOOKUP(A2, Revenue2023, 2, FALSE)"
named_ranges = ["Revenue2023", "Expenses2023"]
formula_type = identify_formula_type(formula, named_ranges)
print(f"Formula type: {formula_type}")
# Out:
# Formula type: Named Range

# %%
FILE_NAME               = 'TEST_CASE.xlsm'
FUNC_PATH               = r'/Users/westhomas/Desktop/ALFRED/1__REPORT_AUTOMATION/XML_PROJECT/PROJECT_PART_1/ALFRED_AI/REFERENCE_FILES/FUNCTIONS.xlsx'
ROOT                    = r'/Users/westhomas/Desktop/ALFRED/1__REPORT_AUTOMATION/XML_PROJECT/PROJECT_PART_1/ALFRED_AI'
FILE_PATH               = ROOT + '/' + FILE_NAME

LABEL_OPTIONS           = ['SETTINGS', 'DATA_CONENECTION', 'INPUT_DATA', 'WORKING', 'OUTPUT']
INPUT_OPTIONS           = ['SQL', 'EXTERNAL_CONNECTION', 'PASTED', 'COMBINATION']
INPUT_CHOICE            = 2


LABELS                  = { 'Overview'              : 'SETTINGS',
                            'Mapping'               : 'INPUT_DATA',
                            'Instrument_Table'      : 'OUTPUT',
                            'DT_P'                  : 'DATA_CONENECTION',
                            'Sheet1'                : 'INPUT_DATA',
                            'Sheet2'                : 'INPUT_DATA',
                            'Sheet3'                : 'INPUT_DATA',
                            'Sheet4'                : 'INPUT_DATA',
                            'Sheet5'                : 'INPUT_DATA',
                            'o1'                    : 'WORKING',
                            'o2'                    : 'WORKING',
                            'o3'                    : 'WORKING',
                            'o4'                    : 'WORKING',
                            'o5'                    : 'WORKING',
                            'o10'                   : 'WORKING',
                            'OP-10'                 : 'WORKING',
                            'Unique_Items'          : 'WORKING',
                            'PAI'                   : 'INPUT_DATA',
                            'Reference'             : 'INPUT_DATA',
                            'FX'                    : 'INPUT_DATA',
                            'PMS'                   : 'INPUT_DATA',
                            'Port_ID'               : 'INPUT_DATA',
                            'FUNCS'                 : 'WORKING'
                        }



EXCEL_PARSED            = EXCEL_DATA_PARSER(FILE_PATH, LABELS)
OUTPUT                  = EXCEL_PARSED.GET_DATA()
OUTPUT['EXT']
# Out:
# {'xl/drawings/drawing1.xml': [{'TYPE': 'SHAPE',
#    'NAME': 'Rectangle: Rounded Corners 1',
#    'MACRO': 'Sheet2.Full_Process',
#    'TEXT': 'Stage 1 Retrieve Data'},
#   {'TYPE': 'SHAPE',
#    'NAME': 'Rectangle: Rounded Corners 2',
#    'MACRO': 'Sheet2.Process_Changes',
#    'TEXT': 'Stage  3 Run Process'},
#   {'TYPE': 'SHAPE',
#    'NAME': 'Rectangle: Rounded Corners 3',
#    'MACRO': 'Sheet2.Process_complete',
#    'TEXT': 'Stage  4 Final  SOF Processes'},
#   {'TYPE': 'SHAPE',
#    'NAME': 'Rectangle: Rounded Corners 4',
#    'MACRO': 'Sheet2.PASTING',
#    'TEXT': 'Stage  2 Formatting'},
#   {'TYPE': 'SHAPE',
#    'NAME': 'Rectangle: Rounded Corners 5',
#    'MACRO': 'Sheet2.SCALING_FINAL',
#    'TEXT': 'Stage  5 Final  EET Processes'},
#   {'TYPE': 'SHAPE',
#    'NAME': 'Rectangle: Rounded Corners 6',
#    'MACRO': 'Sheet2.Export_File',
#    'TEXT': 'Stage  6 Export File'},
#   {'TYPE': 'SHAPE',
#    'NAME': 'Rectangle: Rounded Corners 7',
#    'MACRO': 'Sheet2.Full_Run',
#    'TEXT': 'All  Stages Full Process Run'}],
#  'xl/drawings/drawing2.xml': []}
