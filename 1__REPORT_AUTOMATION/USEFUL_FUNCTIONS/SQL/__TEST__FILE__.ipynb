# %%
import pandas as pd
import warnings

warnings.filterwarnings("ignore")




def READ_EXCEL(FILE_PATH):

    FUNCTIONS, TABLE_NAMES      = [], []
    REFERENCE                   = pd.read_excel(FILE_PATH, sheet_name=0)

    for i in range(1,10):       FUNCTIONS.append(pd.read_excel(FILE_PATH, sheet_name=i))

    for a in range(len(REFERENCE['TABLE NAME'])): TABLE_NAMES.append(REFERENCE.at[a, 'TABLE NAME'])


    return TABLE_NAMES, FUNCTIONS

# %%
EXCEL_FUNCS_FOLDER                  = r'/Users/westhomas/Desktop/ALFRED/1__REPORT_AUTOMATION/REFERENCE_FILES/UPLOAD_TABLES/'
FILE_EXTRA                          = "AST"
EXCEL_FILE_NAME                     = 'AST_RAW_DATA_SQL_UPLOAD'


EXCEL_TEST_PATH                     = EXCEL_FUNCS_FOLDER + '/' + FILE_EXTRA + '/' + EXCEL_FILE_NAME + '.xlsx'
TABLE_NAMES, FUNCTIONS              = READ_EXCEL(EXCEL_TEST_PATH)

# %%
TABLE_NAMES
# Out:
# ['tvfGetDT_P_ExpectedCreditLossProvision_By_Class',
#  'tvfGetDT_P_InvestmentInitialInformation',
#  'tvfGetDT_P_ELRvsSpecificProvisions_RawData',
#  'tvfGetDT_P_Clientreporting_PortfolioPositions_SPAR',
#  'tvfGetDT_P_FundamentalDataListing',
#  'tvfGetDT_P_PortfolioInstrumentlisting_CreditFacility',
#  'tvfGetDT_P_PortfolioPositionsListing',
#  'tvfGetDT_P_FundamentalDataListing',
#  'MANAGER_NAMING_MAP']

# %%
FUNCTIONS[0]
# Out:
#      pId                                          Portfolio  \
# 0     14  SC FPT Private Debt Fund LP (Freeport) - Class A1
# 1     14  SC FPT Private Debt Fund LP (Freeport) - Class A1
# 2     14  SC FPT Private Debt Fund LP (Freeport) - Class A1
# 3     14  SC FPT Private Debt Fund LP (Freeport) - Class A1
# 4     14  SC FPT Private Debt Fund LP (Freeport) - Class A1
# ..   ...                                                ...
# 798  263        Apera European Private Debt Fund - Class A1
# 799  263        Apera European Private Debt Fund - Class A1
# 800  263        Apera European Private Debt Fund - Class A1
# 801  263        Apera European Private Debt Fund - Class A1
# 802  263        Apera European Private Debt Fund - Class A1
#
#                                                   Name  AIDAID  \
# 0    Five Star Parks and Attractions (Freeport) - T...   98462
# 1    Five Star Parks and Attractions (Freeport) - R...   98463
# 2    Five Star Parks and Attractions (Freeport) - D...   98464
# 3                 Peoplease (TLC) (FPT) - Term Loan 1L   99122
# 4                  Peoplease (TLC) (FPT) - Revolver 1L   99129
# ..                                                 ...     ...
# 798        Sohonet (Apera) - Delayed Draw Term Loan 1L   84139
# 799       Sohonet (Apera) - Delayed Draw Term Loan USD   85461
# 800  Infratech BAU (Project Wide) (Apera) - Term Lo...   87830
# 801  Flore Participations (Apera) - Unitranche Term...   87995
# 802  Flore Participations (Apera) - Acquisition DDT...   88012
#
#                                    Borrower Name  AIDAParentId    Platform  \
# 0     Five Star Parks and Attractions (Freeport)         98461  US Onshore
# 1     Five Star Parks and Attractions (Freeport)         98461  US Onshore
# 2     Five Star Parks and Attractions (Freeport)         98461  US Onshore
# 3                                Peoplease (FPT)         85712  US Onshore
# 4                                Peoplease (FPT)         85712  US Onshore
# ..                                           ...           ...         ...
# 798                              Sohonet (Apera)         84137    European
# 799                              Sohonet (Apera)         84137    European
# 800         Infratech BAU (Project Wide) (Apera)         87829    European
# 801  Flore Participations Pinson Paysage (Apera)         80523    European
# 802  Flore Participations Pinson Paysage (Apera)         80523    European
#
#     Manager                    Loan Type                  Sector  ...  \
# 0       FPT                    Term Loan  Consumer Discretionary  ...
# 1       FPT    Revolving Credit Facility  Consumer Discretionary  ...
# 2       FPT      Delayed Drawn Term Loan  Consumer Discretionary  ...
# 3       FPT                    Term Loan             Industrials  ...
# 4       FPT    Revolving Credit Facility             Industrials  ...
# ..      ...                          ...                     ...  ...
# 798   Apera      Delayed Drawn Term Loan  Information Technology  ...
# 799   Apera  Term Loan (EU late funding)  Information Technology  ...
# 800   Apera                    Term Loan             Industrials  ...
# 801   Apera                    Term Loan             Industrials  ...
# 802   Apera      Delayed Drawn Term Loan             Industrials  ...
#
#     Total Provision (Base) Total Provision (Local) LXID/ISIN  \
# 0             15408.820188            15408.820188     98462
# 1               -14.926527              -14.926527     98463
# 2              1040.581983             1040.581983     98464
# 3             31229.426894            31229.426894     99122
# 4               511.180540              511.180540  LX207917
# ..                     ...                     ...       ...
# 798               0.222252                0.190012  LX193474
# 799            1453.743160             1570.042612     85461
# 800            5026.777219             5026.777219     87830
# 801            4256.233367             4256.233367     87995
# 802            2708.512048             2708.512048     88012
#
#      European Legal Entity  Portfolio Position Source  Is Viridium Advisory  \
# 0                      NaN                         WF                    No
# 1                      NaN                         WF                    No
# 2                      NaN                         WF                    No
# 3                      NaN                         WF                    No
# 4                      NaN                         WF                    No
# ..                     ...                        ...                   ...
# 798               Lux Sarl                         WF                    No
# 799               Lux Sarl                         WF                    No
# 800                Lux AIF                         WF                    No
# 801               Lux Sarl                         WF                    No
# 802               Lux Sarl                         WF                    No
#
#      PathHash  IsGreater (General Provision)  IsGreater (Specific Provision)  \
# 0     9.67.14                             No                              No
# 1     9.67.14                            Yes                              No
# 2     9.67.14                             No                              No
# 3     9.67.14                             No                              No
# 4     9.67.14                             No                              No
# ..        ...                            ...                             ...
# 798  9.67.263                             No                              No
# 799  9.67.263                             No                              No
# 800  9.67.263                             No                              No
# 801  9.67.263                             No                              No
# 802  9.67.263                             No                              No
#
#      IsGreater (Total Provision)
# 0                             No
# 1                            Yes
# 2                             No
# 3                             No
# 4                             No
# ..                           ...
# 798                           No
# 799                           No
# 800                           No
# 801                           No
# 802                           No
#
# [803 rows x 44 columns]

# %%
from SQL import SQL_DATA_SAVE, SQL_DATA_READ, CREATE_TABLES, DELETE_TABLES, LOAD_TABLES

DETAILS                           = {"POSTGRES_HOSTNAME"    : 'ENKIINVESTMENTS-186.postgres.eu.pythonanywhere-services.com',
                                     "POSTGRES_HOST_PORT"   : 10186,
                                     "SSH_USER_NAME"        : 'ENKIINVESTMENTS',
                                     "SSH_PASSWORD"         : 'BRYONYBUTTON0104',
                                     "USERNAME"             : "super",
                                     "PASSWORD"             : 'BRYONYBUTTON0104',
                                     "DB_NAME"              : 'myappdb',
                                     "HOST"                 : '127.0.0.1'}





#DELETE      = DELETE_TABLES(DETAILS, DROP_TABLE)
#CREATE      = CREATE_TABLES(DETAILS, TABLE_NAME, INPUT_CRITERIA)

#ERROR       = SQL_DATA_SAVE(INPUT_DF, TABLE_NAME, DETAILS)
#DB          = SQL_DATA_READ(TABLE_NAMES, DETAILS)
#TABLES      = LOAD_TABLES(DETAILS)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from SQL import SQL_DATA_SAVE, SQL_DATA_READ, CREATE_TABLES, DELETE_TABLES, LOAD_TABLES
#       3 DETAILS                           = {"POSTGRES_HOSTNAME"    : 'ENKIINVESTMENTS-186.postgres.eu.pythonanywhere-services.com',
#       4                                      "POSTGRES_HOST_PORT"   : 10186,
#       5                                      "SSH_USER_NAME"        : 'ENKIINVESTMENTS',
#    (...)
#       9                                      "DB_NAME"              : 'myappdb',
#      10                                      "HOST"                 : '127.0.0.1'}
#      16 #DELETE      = DELETE_TABLES(DETAILS, DROP_TABLE)
#      17 #CREATE      = CREATE_TABLES(DETAILS, TABLE_NAME, INPUT_CRITERIA)
#      18
#      19 #ERROR       = SQL_DATA_SAVE(INPUT_DF, TABLE_NAME, DETAILS)
#      20 #DB          = SQL_DATA_READ(TABLE_NAMES, DETAILS)
#      21 #TABLES      = LOAD_TABLES(DETAILS)
#
# File ~/Desktop/ALFRED/1__REPORT_AUTOMATION/USEFUL_FUNCTIONS/SQL/SQL.py:6
#       5 from datetime import datetime, timedelta, date
# ----> 6 from sqlalchemy import create_engine
#       7 import psycopg2 as pg
#       8 import pandas as pd
#
# ModuleNotFoundError: No module named 'sqlalchemy'

# %%
INPUT_CRITERIA      = ["TEST VARCHAR(255) NOT NULL"]

for NAME in TABLE_NAMES:
    CREATE      = CREATE_TABLES(DETAILS, NAME, INPUT_CRITERIA)

# %%
INPUT_DF            = ""
DROP_TABLE          = "algo_list"
TABLE_NAMES         = "algo_list"

# %%
TABLES      = LOAD_TABLES(DETAILS)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 TABLES      = LOAD_TABLES(DETAILS)
#
# NameError: name 'LOAD_TABLES' is not defined
